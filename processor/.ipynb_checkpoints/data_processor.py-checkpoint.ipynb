# %%
import datetime
import dateparser
import pandas as pd
import numpy as np
import re
import os

# %%
beers = pd.read_csv('../data/beer_info.csv')
reviews = pd.read_csv('../data/beer_reviews.csv')

# %%
beers.head()
# Out:
#    BAscore  abv  beer_id                                          beer_img  \
# 0     4.35  7.0        1  https://cdn.beeradvocate.com/im/beers/141544.jpg
# 1     3.59  7.0        2   https://cdn.beeradvocate.com/im/beers/94770.jpg
# 2     3.97  7.0        3  https://cdn.beeradvocate.com/im/beers/118069.jpg
# 3     3.97  6.5        4   https://cdn.beeradvocate.com/im/beers/93370.jpg
# 4     3.96  6.0        5  https://cdn.beeradvocate.com/im/beers/180860.jpg
#
#                  beer_name    beer_style                      brewery  \
# 0         Yakima Fresh Hop  American IPA     Columbus Brewing Company
# 1             Red Clay IPA  American IPA  Sunken City Brewing Company
# 2              Traitor IPA  American IPA  Badger Hill Brewing Company
# 3  OG Wheat India Pale Ale  American IPA        10 Barrel Brewing Co.
# 4                 Streaker  American IPA           Rhinegeist Brewery
#
#                                                 desc  num_reviews ranking
# ...

# %%
reviews.head()
# Out:
#    beer_id        posted                                            ratings  \
# 0        1  Nov 07, 2014                                     207 characters
# 1        1  Nov 08, 2018  look: 3.75 | smell: 3.25 | taste: 4.5 | feel: ...
# 2        1  Oct 24, 2018  look: 4 | smell: 4.75 | taste: 4.5 | feel: 4.5...
# 3        1  Oct 21, 2016  look: 4.5 | smell: 5 | taste: 4.75 | feel: 4.5...
# 4        1  Dec 18, 2016  look: 4 | smell: 4.5 | taste: 4.5 | feel: 4 | ...
#
#    review_id  score                                               text  \
# 0          1   4.40  Growler fill from the Ohio Taproom. Take advan...
# 1          2   4.08  L: Gold, transparent. Gorgeous head with nice ...
# 2          3   4.53  This is a good Fresh Hop ale! Great dank taste...
# 3          4   4.77  Bottle dated 10/17/16, poured into tulip. Mild...
# 4          5   4.32  12 ounce bottle into tulip glass, bottled on 1...
#
#            username
# 0  Swettenham_Shire
# 1      KurtisCarman
# ...

# %%
#Clean Ratings
# if string characters appears, than user did not give a ratings breakdown. so clear the line.
r = re.compile('characters')
ratings = reviews.ratings
ratings = ['' if r.search(rating) else rating for rating in ratings]
r = re.compile('look|smell|taste|feel|overall|: ')
ratings = [r.sub('',rating).split(' | ') for rating in ratings]
ratings = [ra if ra == [''] else list(map(float, ra)) for ra in ratings]

# %%
reviews.ratings = ratings

# %%
reviews.head()
# Out:
#    beer_id        posted                        ratings  review_id  score  \
# 0        1  Nov 07, 2014                             []          1   4.40
# 1        1  Nov 08, 2018  [3.75, 3.25, 4.5, 4.25, 4.25]          2   4.08
# 2        1  Oct 24, 2018     [4.0, 4.75, 4.5, 4.5, 4.5]          3   4.53
# 3        1  Oct 21, 2016    [4.5, 5.0, 4.75, 4.5, 4.75]          4   4.77
# 4        1  Dec 18, 2016      [4.0, 4.5, 4.5, 4.0, 4.0]          5   4.32
#
#                                                 text          username
# 0  Growler fill from the Ohio Taproom. Take advan...  Swettenham_Shire
# 1  L: Gold, transparent. Gorgeous head with nice ...      KurtisCarman
# 2  This is a good Fresh Hop ale! Great dank taste...     ChilliHeights
# 3  Bottle dated 10/17/16, poured into tulip. Mild...         jsidonis7
# 4  12 ounce bottle into tulip glass, bottled on 1...         superspak

# %%
#Clean posted date
posted = reviews.posted

# %%
def parse_dates(text, origin):
    #Parses absolute and relative dates    
    return datetime.strptime(text, '%b %d, %Y')
    
        
    #return dateparser.parse(text, settings={'RELATIVE_BASE': origin})

# %%
scraping_date = dateparser.parse('Jul 3, 2019')
[parse_dates(post, scraping_date) for post in posted.sample(1000)]
# Out:
# [datetime.datetime(2011, 3, 31, 0, 0),
#  datetime.datetime(2007, 3, 3, 0, 0),
#  datetime.datetime(2008, 9, 13, 0, 0),
#  datetime.datetime(2004, 4, 20, 0, 0),
#  datetime.datetime(2014, 12, 30, 0, 0),
#  datetime.datetime(2009, 8, 19, 0, 0),
#  datetime.datetime(2012, 5, 29, 0, 0),
#  datetime.datetime(2009, 3, 1, 0, 0),
#  datetime.datetime(2008, 3, 21, 0, 0),
#  datetime.datetime(2011, 9, 2, 0, 0),
#  datetime.datetime(2008, 11, 15, 0, 0),
#  datetime.datetime(2006, 6, 19, 0, 0),
#  datetime.datetime(2018, 10, 3, 0, 0),
#  datetime.datetime(2011, 1, 18, 0, 0),
#  datetime.datetime(2013, 1, 10, 0, 0),
#  datetime.datetime(2017, 5, 28, 0, 0),
#  datetime.datetime(2005, 10, 3, 0, 0),
#  datetime.datetime(2015, 1, 11, 0, 0),
#  datetime.datetime(2014, 10, 31, 0, 0),
#  datetime.datetime(2014, 4, 7, 0, 0),
#  datetime.datetime(2009, 3, 23, 0, 0),
#  datetime.datetime(2010, 8, 20, 0, 0),
#  datetime.datetime(2012, 4, 7, 0, 0),
#  datetime.datetime(2007, 2, 21, 0, 0),
# ...
